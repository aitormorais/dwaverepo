# %% [markdown]
# <div>
# <img src="https://www.nebrija.com/images/logos/logotipo-universidad-nebrija.jpg" width="200">
# </div>
#
# **MODELOS DE PROGRAMACION: MODELO ADIABATICO** -
# Prof: Carmen Pellicer Lostao

# %% [markdown]
# # D-WAVE OCEAN

# %% [markdown]
# ## Intro

# %% [markdown]
# Read the docs for further info: https://docs.ocean.dwavesys.com/en/stable/getting_started.html
#
# **New to Jupyter Notebooks?** JNs are divided into text or code cells. Pressing the **Run** button in the menu bar moves to the next cell. Code cells are marked by an "In: \[\]" to the left; when run, an asterisk displays until code completion: "In: \[\*\]".

# %% [markdown]
# ## Installing Ocean SDK
#
# D-Wave Ocean SDK (Ocean) is a collection of software that uses D-Wave Machines. It is easy to use various features from Python.
#
# Github: https://github.com/dwavesystems/dwave-ocean-sdk
#
# Document: https://docs.ocean.dwavesys.com/en/latest/
#
# Guide: https://docs.ocean.dwavesys.com/en/stable/overview/install.html
#
# To install Ocean, use pip as described in the link above, or clone the github repository.

# %%
# !pip install dwave-ocean-sdk
# Out:
# Collecting dwave-ocean-sdk
#   Downloading dwave_ocean_sdk-6.7.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting dimod==0.12.13 (from dwave-ocean-sdk)
#   Downloading dimod-0.12.13-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting dwave-cloud-client==0.11.2 (from dwave-ocean-sdk)
#   Downloading dwave_cloud_client-0.11.2-py3-none-any.whl.metadata (5.3 kB)
# Collecting dwave-greedy==0.3.0 (from dwave-ocean-sdk)
#   Downloading dwave_greedy-0.3.0-py3-none-any.whl (10 kB)
# Collecting dwave-hybrid==0.6.10 (from dwave-ocean-sdk)
#   Downloading dwave_hybrid-0.6.10-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.8/74.8 kB 2.0 MB/s eta 0:00:00
# Collecting dwave-inspector==0.4.4 (from dwave-ocean-sdk)
#   Downloading dwave_inspector-0.4.4-py3-none-any.whl.metadata (4.4 kB)
# Collecting dwave-neal==0.6.0 (from dwave-ocean-sdk)
#   Downloading dwave_neal-0.6.0-py3-none-any.whl (8.7 kB)
# Collecting dwave-networkx==0.8.14 (from dwave-ocean-sdk)
#   Downloading dwave_networkx-0.8.14-py3-none-any.whl.metadata (2.6 kB)
# Collecting dwave-preprocessing==0.6.4 (from dwave-ocean-sdk)
#   Downloading dwave_preprocessing-0.6.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Collecting dwave-samplers==1.2.0 (from dwave-ocean-sdk)
#   Downloading dwave_samplers-1.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.8 kB)
# Collecting dwave-system==1.22.0 (from dwave-ocean-sdk)
#   Downloading dwave_system-1.22.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dwave-tabu==0.5.0 (from dwave-ocean-sdk)
#   Downloading dwave_tabu-0.5.0-py3-none-any.whl (9.2 kB)
# Collecting dwavebinarycsp==0.2.0 (from dwave-ocean-sdk)
#   Downloading dwavebinarycsp-0.2.0-py3-none-any.whl (35 kB)
# Collecting minorminer==0.2.13 (from dwave-ocean-sdk)
#   Downloading minorminer-0.2.13-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Collecting penaltymodel==1.0.2 (from dwave-ocean-sdk)
#   Downloading penaltymodel-1.0.2-py3-none-any.whl (36 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.17.3 in /home/codespace/.local/lib/python3.10/site-packages (from dimod==0.12.13->dwave-ocean-sdk) (1.26.2)
# Requirement already satisfied: requests>=2.18 in /home/codespace/.local/lib/python3.10/site-packages (from requests[socks]>=2.18->dwave-cloud-client==0.11.2->dwave-ocean-sdk) (2.31.0)
# Collecting pydantic<3,>=2 (from dwave-cloud-client==0.11.2->dwave-ocean-sdk)
#   Downloading pydantic-2.5.2-py3-none-any.whl.metadata (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.2/65.2 kB 1.8 MB/s eta 0:00:00
# Collecting homebase>=1.0 (from dwave-cloud-client==0.11.2->dwave-ocean-sdk)
#   Downloading homebase-1.0.1-py2.py3-none-any.whl (11 kB)
# Collecting click>=7.0 (from dwave-cloud-client==0.11.2->dwave-ocean-sdk)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.10/site-packages (from dwave-cloud-client==0.11.2->dwave-ocean-sdk) (2.8.2)
# Collecting plucky>=0.4.3 (from dwave-cloud-client==0.11.2->dwave-ocean-sdk)
#   Downloading plucky-0.4.3-py2.py3-none-any.whl (10 kB)
# Collecting diskcache>=5.2.1 (from dwave-cloud-client==0.11.2->dwave-ocean-sdk)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: packaging>=19 in /home/codespace/.local/lib/python3.10/site-packages (from dwave-cloud-client==0.11.2->dwave-ocean-sdk) (23.2)
# Collecting werkzeug>=2.2 (from dwave-cloud-client==0.11.2->dwave-ocean-sdk)
#   Downloading werkzeug-3.0.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/codespace/.local/lib/python3.10/site-packages (from dwave-cloud-client==0.11.2->dwave-ocean-sdk) (4.8.0)
# Collecting authlib<2,>=1.2 (from dwave-cloud-client==0.11.2->dwave-ocean-sdk)
#   Downloading Authlib-1.2.1-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting importlib-metadata>=5.0.0 (from dwave-cloud-client==0.11.2->dwave-ocean-sdk)
#   Downloading importlib_metadata-7.0.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: networkx in /home/codespace/.local/lib/python3.10/site-packages (from dwave-hybrid==0.6.10->dwave-ocean-sdk) (3.2.1)
# Collecting Flask>=2.2 (from dwave-inspector==0.4.4->dwave-ocean-sdk)
#   Downloading flask-3.0.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting networkx (from dwave-hybrid==0.6.10->dwave-ocean-sdk)
#   Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 33.8 MB/s eta 0:00:00:00:01
# Requirement already satisfied: scipy>=1.7.3 in /home/codespace/.local/lib/python3.10/site-packages (from dwave-system==1.22.0->dwave-ocean-sdk) (1.11.3)
# Collecting fasteners>=0.15 (from minorminer==0.2.13->dwave-ocean-sdk)
#   Downloading fasteners-0.19-py3-none-any.whl.metadata (4.9 kB)
# Collecting rectangle-packer>=2.0.1 (from minorminer==0.2.13->dwave-ocean-sdk)
#   Downloading rectangle_packer-2.0.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting cryptography>=3.2 (from authlib<2,>=1.2->dwave-cloud-client==0.11.2->dwave-ocean-sdk)
#   Downloading cryptography-41.0.7-cp37-abi3-manylinux_2_28_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: Jinja2>=3.1.2 in /home/codespace/.local/lib/python3.10/site-packages (from Flask>=2.2->dwave-inspector==0.4.4->dwave-ocean-sdk) (3.1.2)
# Collecting itsdangerous>=2.1.2 (from Flask>=2.2->dwave-inspector==0.4.4->dwave-ocean-sdk)
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting blinker>=1.6.2 (from Flask>=2.2->dwave-inspector==0.4.4->dwave-ocean-sdk)
#   Downloading blinker-1.7.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting zipp>=0.5 (from importlib-metadata>=5.0.0->dwave-cloud-client==0.11.2->dwave-ocean-sdk)
#   Downloading zipp-3.17.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting annotated-types>=0.4.0 (from pydantic<3,>=2->dwave-cloud-client==0.11.2->dwave-ocean-sdk)
#   Downloading annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.14.5 (from pydantic<3,>=2->dwave-cloud-client==0.11.2->dwave-ocean-sdk)
#   Downloading pydantic_core-2.14.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->dwave-cloud-client==0.11.2->dwave-ocean-sdk) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.18->requests[socks]>=2.18->dwave-cloud-client==0.11.2->dwave-ocean-sdk) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.18->requests[socks]>=2.18->dwave-cloud-client==0.11.2->dwave-ocean-sdk) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from requests>=2.18->requests[socks]>=2.18->dwave-cloud-client==0.11.2->dwave-ocean-sdk) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.18->requests[socks]>=2.18->dwave-cloud-client==0.11.2->dwave-ocean-sdk) (2023.7.22)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]>=2.18->dwave-cloud-client==0.11.2->dwave-ocean-sdk)
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/codespace/.local/lib/python3.10/site-packages (from werkzeug>=2.2->dwave-cloud-client==0.11.2->dwave-ocean-sdk) (2.1.3)
# Requirement already satisfied: cffi>=1.12 in /home/codespace/.local/lib/python3.10/site-packages (from cryptography>=3.2->authlib<2,>=1.2->dwave-cloud-client==0.11.2->dwave-ocean-sdk) (1.16.0)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=3.2->authlib<2,>=1.2->dwave-cloud-client==0.11.2->dwave-ocean-sdk) (2.21)
# Downloading dwave_ocean_sdk-6.7.1-py3-none-any.whl (8.4 kB)
# Downloading dimod-0.12.13-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.4/18.4 MB 53.1 MB/s eta 0:00:00:00:0100:01
# Downloading dwave_cloud_client-0.11.2-py3-none-any.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.8/138.8 kB 4.2 MB/s eta 0:00:00
# Downloading dwave_inspector-0.4.4-py3-none-any.whl (31 kB)
# Downloading dwave_networkx-0.8.14-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.4/102.4 kB 2.9 MB/s eta 0:00:00
# Downloading dwave_preprocessing-0.6.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 10.5 MB/s eta 0:00:0000:0100:01m
# Downloading dwave_samplers-1.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 31.5 MB/s eta 0:00:0000:01:00:01
# Downloading dwave_system-1.22.0-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 2.8 MB/s eta 0:00:00
# Downloading minorminer-0.2.13-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 10.3 MB/s eta 0:00:0000:010:01m
# Downloading Authlib-1.2.1-py2.py3-none-any.whl (215 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.3/215.3 kB 6.5 MB/s eta 0:00:00
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 2.9 MB/s eta 0:00:00
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 1.2 MB/s eta 0:00:00
# Downloading fasteners-0.19-py3-none-any.whl (18 kB)
# Downloading flask-3.0.0-py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.7/99.7 kB 3.0 MB/s eta 0:00:00
# Downloading importlib_metadata-7.0.0-py3-none-any.whl (23 kB)
# Downloading pydantic-2.5.2-py3-none-any.whl (381 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.9/381.9 kB 10.4 MB/s eta 0:00:0000:01
# Downloading pydantic_core-2.14.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 35.3 MB/s eta 0:00:00:00:01
# Downloading rectangle_packer-2.0.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (305 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.6/305.6 kB 9.1 MB/s eta 0:00:00
# Downloading werkzeug-3.0.1-py3-none-any.whl (226 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 6.8 MB/s eta 0:00:00
# Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Downloading blinker-1.7.0-py3-none-any.whl (13 kB)
# Downloading cryptography-41.0.7-cp37-abi3-manylinux_2_28_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 53.2 MB/s eta 0:00:00:00:01
# Downloading zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Installing collected packages: rectangle-packer, plucky, homebase, zipp, werkzeug, PySocks, pydantic-core, networkx, itsdangerous, fasteners, diskcache, dimod, click, blinker, annotated-types, pydantic, penaltymodel, importlib-metadata, Flask, dwave-samplers, dwave-preprocessing, dwave-networkx, cryptography, minorminer, dwavebinarycsp, dwave-tabu, dwave-neal, dwave-greedy, authlib, dwave-cloud-client, dwave-system, dwave-inspector, dwave-hybrid, dwave-ocean-sdk
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.2.1
#     Uninstalling networkx-3.2.1:
#       Successfully uninstalled networkx-3.2.1
# Successfully installed Flask-3.0.0 PySocks-1.7.1 annotated-types-0.6.0 authlib-1.2.1 blinker-1.7.0 click-8.1.7 cryptography-41.0.7 dimod-0.12.13 diskcache-5.6.3 dwave-cloud-client-0.11.2 dwave-greedy-0.3.0 dwave-hybrid-0.6.10 dwave-inspector-0.4.4 dwave-neal-0.6.0 dwave-networkx-0.8.14 dwave-ocean-sdk-6.7.1 dwave-preprocessing-0.6.4 dwave-samplers-1.2.0 dwave-system-1.22.0 dwave-tabu-0.5.0 dwavebinarycsp-0.2.0 fasteners-0.19 homebase-1.0.1 importlib-metadata-7.0.0 itsdangerous-2.1.2 minorminer-0.2.13 networkx-2.8.8 penaltymodel-1.0.2 plucky-0.4.3 pydantic-2.5.2 pydantic-core-2.14.5 rectangle-packer-2.0.2 werkzeug-3.0.1 zipp-3.17.0

# %%
#Advanced users might directly install the latest (development) SDK from the D-Wave GitHub repository using a command such as,
#!pip install git+https://github.com/dwavesystems/dwave-ocean-sdk

# %%
#Alternatively, you can clone the dwave-ocean-sdk repo and install the SDK to your virtual environment; for example:
#!git clone https://github.com/dwavesystems/dwave-ocean-sdk.git
#!cd dwave-ocean-sdk
#!python setup.py install

# %% [markdown]
# ## Configuring Access to Leap’s Solvers

# %% [markdown]
# D-Wave’s **Solver API (SAPI)** provides access to the solvers—compute resources for solving problems, such as a D-Wave quantum computers and quantum-classical hybrid solvers—hosted in the Leap quantum cloud.
#
# You need SAPI credentials to access these resources. These credentials are **a token sting** that identifies your account in Dwave.

# %% [markdown]
# ### Loading credentials in a runtime variable

# %% [markdown]
# We can create a variable that stores the access token string and use it explicitly when calling a solver

# %%
#setting the value of your token in a variable, hard-coded in the notebook (not-recommended)
token="my SAPI token"

# %%
#importing the access token from a file (recommended)
import credentials as cre
# set the connection information as an option
endpoint = 'https://cloud.dwavesys.com/sapi'
token = cre.token

# %% [markdown]
# Example: Use the token to execute a solver

# %%
from dwave.system import DWaveSampler, EmbeddingComposite
sampler = EmbeddingComposite(DWaveSampler(token=token))
h = {}
J = {('s1', 's2'): -0.5}
sampleset = sampler.sample_ising(h, J, num_reads=1000)
print(sampleset)
# Out:
#   s1 s2 energy num_oc. chain_.
# 0 -1 -1   -0.5     410     0.0
# 1 +1 +1   -0.5     590     0.0
# ['SPIN', 2 rows, 1000 samples, 2 variables]

# %% [markdown]
# ### Ocean tools env set-up

# %% [markdown]
# The dwave-ocean-sdk includes an interactive **CLI program** that steps you through setup a virtual environment with all necesary and interesting tools to work with Dwave systems. (CLI stands for Command Line Interface)
#
# For a full and easy development experience it is recommended that before you start writing code, you complete the setup of your environment.
#
# It is also recommended that you include the two last steps:
#
# Install Contributor Ocean Tools, adds **non-open-source tools** such as the **Problem Inspector**.

# %%
#Install optional non-open-source Ocean packages
#see help for available commands and then run the install
# !dwave install --help

# %%
# !dwave install
# Out:
# Nothing to do. Try "dwave install --help".

# %% [markdown]
# In the virtual environment you created as part of Installing Ocean Tools, run the **dwave setup** command. Once the environment is configured in the setup, you will not need to include the token or other account params in the code.
#
# The setup creates a **configuration file** that Ocean primitives will automatically use to include these params for you when using the SAPI.
#
# New users can accept the dwave setup command’s defaults (press Enter) for all prompts except the authentication token, which is displayed on the Leap dashboard for your account. Section Configuring Access to Leap’s Solvers explains how you can update your work environment’s configuration at any time.

# %%
#run in terminal
# !dwave setup

# %% [markdown]
# Example: Use the config file created in the setup to execute a solver. No token

# %%
from dwave.system import DWaveSampler, EmbeddingComposite
sampler = EmbeddingComposite(DWaveSampler())
h = {}
J = {('s1', 's2'): -0.5}
sampleset = sampler.sample_ising(h, J, num_reads=1000)
print(sampleset)
# Out:
#   s1 s2 energy num_oc. chain_.
# 0 -1 -1   -0.5     508     0.0
# 1 +1 +1   -0.5     492     0.0
# ['SPIN', 2 rows, 1000 samples, 2 variables]

# %% [markdown]
# #### Working with the config file
#
# To manage or change the environment configuration file at any time we use the `dwave config command` also available in the DWave CLI program

# %%
#see all command available
# !dwave config --help

# %%
#inspect the config file
# !dwave config inspect

# %%
#see where it is
# !dwave config ls

# %%
#use linux cat command to see it
# !cat /home/codespace/.config/dwave/dwave.conf

# %%
#execute in terminal
#IMPORTANT: do not include [] or "" in any param
# !dwave config create --full

# %%
# !cat /home/codespace/.config/dwave/dwave.conf

# %% [markdown]
# Example: using dwave CLI to see the available solvers, their parameters, and properties.

# %%
#na-west-1 eu-central-1
# !dwave solvers  --list --all --region na-west-1

# %% [markdown]
# Example: using dwave-cloud-client to query for hybrid solvers.
#
# IMPORTANT: having different config profiles you can select different config params specifying the profile explicitly

# %%
from dwave.cloud import Client
#specify the profile you are using in the Client command -> check that in europe there are not hybrid solvers
with Client.from_config(profile="defaults") as client:
   solvers_list=client.get_solvers(hybrid=True)

for s in solvers_list:
  print(s)

# %% [markdown]
# Example: using dwave-cloud-client to query supported regions.

# %%
with Client.from_config(profile="defaults") as client:
   regions = client.get_regions()
   for code, info in regions.items():
       print(f"{info['name']} ({code}): {info['endpoint']}")

# %% [markdown]
# #### Verify configuration of the virtual environment

# %% [markdown]
# To Verify your configuration in the virtual environment, you can test that your solver access is configured correctly with the interactive CLI.
#
# In your virtual environment, run the dwave ping command

# %%
# !dwave ping --client qpu

# %% [markdown]
# or run a random toy problem to see if everything works

# %%
# !dwave sample --random-problem
